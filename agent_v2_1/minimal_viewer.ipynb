# %%
# %load_ext lab_black
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Run Agent against itself

# %%
# !luxai-s2 main.py main.py -v 2 -s 42 -o replay.html

# %%
# !luxai-s2 main.py main.py -v 2 -s 178220973 -o replay.html
# !luxai-s2 main.py main.py -v 2 -s 42 -o replay.html
# Out:
# player_1, main.py: INFO:root:Starting Log
#
# player_0, main.py: INFO:root:Starting Log
#
# player_1, main.py: INFO:numexpr.utils:Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
#
# player_1, main.py: INFO:numexpr.utils:NumExpr defaulting to 8 threads.
#
# player_0, main.py: INFO:numexpr.utils:Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
#
# player_0, main.py: INFO:numexpr.utils:NumExpr defaulting to 8 threads.
#
# player_0, main.py: INFO:root:initializing agent for player player_0
#
# player_1, main.py: INFO:root:initializing agent for player player_1
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 0
#
# player_0, main.py: INFO:root:player_0 Early setup action {'faction': 'TheBuilders', 'bid': 0}
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 0
#
# player_1, main.py: INFO:root:player_1 Early setup action {'faction': 'TheBuilders', 'bid': 0}
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 1
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 1
#
# player_1, main.py: INFO:root:player_1 Early setup action {}
#
# player_0, main.py: INFO:root:player_0 Early setup action {'spawn': (32, 11), 'metal': 150, 'water': 150}
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 2
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 2
#
# player_0, main.py: INFO:root:player_0 Early setup action {}
#
# player_1, main.py: INFO:root:player_1 Early setup action {'spawn': (13, 4), 'metal': 150, 'water': 150}
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 3
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 3
#
# player_1, main.py: INFO:root:player_1 Early setup action {}
#
# player_0, main.py: INFO:root:player_0 Early setup action {'spawn': (19, 10), 'metal': 150, 'water': 150}
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 4
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 4
#
# player_0, main.py: INFO:root:player_0 Early setup action {}
#
# player_1, main.py: INFO:root:player_1 Early setup action {'spawn': (29, 22), 'metal': 150, 'water': 150}
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 5
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 5
#
# player_1, main.py: INFO:root:player_1 Early setup action {}
#
# player_0, main.py: INFO:root:player_0 Early setup action {'spawn': (35, 15), 'metal': 150, 'water': 150}
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 6
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 6
#
# player_0, main.py: INFO:root:player_0 Early setup action {}
#
# player_1, main.py: INFO:root:player_1 Early setup action {'spawn': (36, 30), 'metal': 150, 'water': 150}
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 7
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 7
#
# player_1, main.py: INFO:root:player_1 Early setup action {}
#
# player_0, main.py: INFO:root:player_0 Early setup action {'spawn': (38, 22), 'metal': 150, 'water': 150}
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 8
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 8
#
# player_0, main.py: INFO:root:player_0 Early setup action {}
#
# player_1, main.py: INFO:root:player_1 Early setup action {'spawn': (44, 21), 'metal': 150, 'water': 150}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 9
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 9
#
# player_0, main.py: INFO:root:factory_0 building Heavy
#
# player_0, main.py: INFO:root:factory_2 building Heavy
#
# player_0, main.py: INFO:root:factory_4 building Heavy
#
# player_0, main.py: INFO:root:factory_6 building Heavy
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {'factory_0': 1, 'factory_2': 1, 'factory_4': 1, 'factory_6': 1}
#
# player_1, main.py: INFO:root:factory_1 building Heavy
#
# player_1, main.py: INFO:root:factory_3 building Heavy
#
# player_1, main.py: INFO:root:factory_5 building Heavy
#
# player_1, main.py: INFO:root:factory_7 building Heavy
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {'factory_1': 1, 'factory_3': 1, 'factory_5': 1, 'factory_7': 1}
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 10
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 10
#
# player_1, main.py: INFO:root:Path len 0 for 0, UnitType.LIGHT, factory_3
#
# player_1, main.py: INFO:root:Path len 0 for 0, UnitType.HEAVY, factory_3
#
# player_0, main.py: INFO:root:player_0 unit_8 assigned to mine_ice (for factory_0)
#
# player_0, main.py: INFO:root:MiningRoutePlanner: picking up desired power to achieve target of 664
#
# player_0, main.py: INFO:root:MiningRoutePlanner: picking up available power 550
#
# player_0, main.py: INFO:root:MiningRoutePlanner: picking up desired power to achieve target of 664
#
# player_0, main.py: INFO:root:MiningRoutePlanner: picking up desired power to achieve target of 664
#
# player_0, main.py: INFO:root:player_0 unit_9 assigned to mine_ice (for factory_2)
#
# player_0, main.py: INFO:root:MiningRoutePlanner: picking up desired power to achieve target of 664
#
# player_0, main.py: INFO:root:MiningRoutePlanner: picking up available power 550
#
# player_0, main.py: INFO:root:MiningRoutePlanner: picking up desired power to achieve target of 664
#
# player_0, main.py: INFO:root:MiningRoutePlanner: picking up desired power to achieve target of 664
#
# player_0, main.py: INFO:root:player_0 unit_10 assigned to mine_ice (for factory_4)
#
# player_0, main.py: INFO:root:MiningRoutePlanner: picking up desired power to achieve target of 664
#
# player_0, main.py: INFO:root:MiningRoutePlanner: picking up available power 550
#
# player_0, main.py: INFO:root:MiningRoutePlanner: picking up desired power to achieve target of 664
#
# player_0, main.py: INFO:root:MiningRoutePlanner: picking up desired power to achieve target of 664
#
# player_0, main.py: INFO:root:player_0 unit_11 assigned to mine_ice (for factory_6)
#
# player_0, main.py: INFO:root:MiningRoutePlanner: picking up desired power to achieve target of 665
#
# player_0, main.py: INFO:root:MiningRoutePlanner: picking up available power 550
#
# player_0, main.py: INFO:root:MiningRoutePlanner: picking up desired power to achieve target of 665
#
# player_0, main.py: INFO:root:MiningRoutePlanner: picking up desired power to achieve target of 665
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 unit_12 assigned to mine_ice (for factory_1)
#
# player_1, main.py: INFO:root:MiningRoutePlanner: picking up desired power to achieve target of 664
#
# player_1, main.py: INFO:root:MiningRoutePlanner: picking up available power 550
#
# player_1, main.py: INFO:root:MiningRoutePlanner: picking up desired power to achieve target of 664
#
# player_1, main.py: INFO:root:MiningRoutePlanner: picking up desired power to achieve target of 664
#
# player_1, main.py: INFO:root:player_1 unit_13 assigned to mine_ice (for factory_3)
#
# player_1, main.py: INFO:root:MiningRoutePlanner: picking up desired power to achieve target of 664
#
# player_1, main.py: INFO:root:MiningRoutePlanner: picking up available power 550
#
# player_1, main.py: INFO:root:MiningRoutePlanner: picking up desired power to achieve target of 664
#
# player_1, main.py: INFO:root:MiningRoutePlanner: picking up desired power to achieve target of 664
#
# player_1, main.py: INFO:root:player_1 unit_14 assigned to mine_ice (for factory_5)
#
# player_1, main.py: INFO:root:MiningRoutePlanner: picking up desired power to achieve target of 665
#
# player_1, main.py: INFO:root:MiningRoutePlanner: picking up available power 550
#
# player_1, main.py: INFO:root:MiningRoutePlanner: picking up desired power to achieve target of 665
#
# player_1, main.py: INFO:root:MiningRoutePlanner: picking up desired power to achieve target of 665
#
# player_1, main.py: INFO:root:player_1 unit_15 assigned to mine_ice (for factory_7)
#
# player_1, main.py: INFO:root:MiningRoutePlanner: picking up desired power to achieve target of 664
#
# player_1, main.py: INFO:root:MiningRoutePlanner: picking up available power 550
#
# player_1, main.py: INFO:root:MiningRoutePlanner: picking up desired power to achieve target of 664
#
# player_1, main.py: INFO:root:MiningRoutePlanner: picking up desired power to achieve target of 664
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 11
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 11
#
# player_0, main.py: INFO:root:factory_0 building Light
#
# player_0, main.py: INFO:root:factory_2 building Light
#
# player_0, main.py: INFO:root:factory_4 building Light
#
# player_0, main.py: INFO:root:factory_6 building Light
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {'factory_0': 0, 'factory_2': 0, 'factory_4': 0, 'factory_6': 0}
#
# player_1, main.py: INFO:root:factory_1 building Light
#
# player_1, main.py: INFO:root:factory_3 building Light
#
# player_1, main.py: INFO:root:factory_5 building Light
#
# player_1, main.py: INFO:root:factory_7 building Light
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {'factory_1': 0, 'factory_3': 0, 'factory_5': 0, 'factory_7': 0}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 12
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 12
#
# player_0, main.py: INFO:root:player_0 unit_16 assigned to clear_rubble (for factory_0)
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: topping up battery
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: unit moving to (31, 13)
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=1.0, value to move=0.7268986145058722
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=10, digs planned (n)=10
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.7268986145058722
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.9086232681323403, value to move=0.551432652308426
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=10, digs planned (n)=10
#
# player_1, main.py: INFO:root:player_1 unit_20 assigned to clear_rubble (for factory_1)
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: topping up battery
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.551432652308426
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: unit moving to (12, 2)
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.6892908153855324, value to move=0.4705222433282904
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=10, digs planned (n)=7
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=1.0, value to move=0.5555283641643911
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: digs_required=13, digs planned (n)=13
#
# player_0, main.py: INFO:root:player_0 unit_17 assigned to clear_rubble (for factory_2)
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: topping up battery
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: unit moving to (19, 12)
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.5555283641643911
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.6944104552054888, value to move=0.4185321167663156
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: digs_required=13, digs planned (n)=13
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=1.0, value to move=0.7176400228297535
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=12, digs planned (n)=12
#
# player_1, main.py: INFO:root:player_1 unit_21 assigned to clear_rubble (for factory_3)
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: topping up battery
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.7176400228297535
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: unit moving to (28, 18)
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.8970500285371917, value to move=0.6356050175076806
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=13, digs planned (n)=13
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=1.0, value to move=0.7564689732052002
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: digs_required=11, digs planned (n)=11
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.6356050175076806
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.7945062718846008, value to move=0.6383159554248774
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=14, digs planned (n)=3
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.7564689732052002
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.9455862165065002, value to move=0.7421067491323354
#
# player_0, main.py: INFO:root:player_0 unit_18 assigned to clear_rubble (for factory_4)
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: digs_required=11, digs planned (n)=11
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: topping up battery
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: unit moving to (33, 15)
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.7421067491323354
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=1.0, value to move=0.7528264682731955
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=11, digs planned (n)=11
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.9276334364154193, value to move=0.38867788654099406
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: digs_required=11, digs planned (n)=4
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.7528264682731955
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_1, main.py: INFO:root:player_1 unit_22 assigned to clear_rubble (for factory_5)
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: topping up battery
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: unit moving to (35, 32)
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.9410330853414944, value to move=0.7051620364526708
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=10, digs planned (n)=10
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=1.0, value to move=0.7305884982275896
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: digs_required=8, digs planned (n)=8
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.7051620364526708
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.7305884982275896
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.8814525455658385, value to move=0.6650167614458354
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=10, digs planned (n)=7
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.913235622784487, value to move=0.7997705859759044
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: digs_required=8, digs planned (n)=8
#
# player_0, main.py: INFO:root:player_0 unit_19 assigned to clear_rubble (for factory_6)
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: topping up battery
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: unit moving to (39, 20)
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.7997705859759044
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.9997132324698805, value to move=0.6060043002760227
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: digs_required=8, digs planned (n)=8
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=1.0, value to move=0.6400000000000001
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=12, digs planned (n)=12
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.6060043002760227
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.6400000000000001
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.7575053753450283, value to move=0.3488146099250249
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: digs_required=9, digs planned (n)=2
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.8, value to move=0.4687056711524766
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=12, digs planned (n)=12
#
# player_1, main.py: INFO:root:player_1 unit_23 assigned to clear_rubble (for factory_7)
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: topping up battery
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: unit moving to (45, 23)
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.4687056711524766
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.5858820889405957, value to move=0.5424518813941391
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=12, digs planned (n)=2
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=1.0, value to move=0.5085095576027573
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: digs_required=13, digs planned (n)=13
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.5085095576027573
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.6356369470034466, value to move=0.2650276199889177
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: digs_required=13, digs planned (n)=13
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.2650276199889177
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.33128452498614713, value to move=0.17622136611624017
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: digs_required=14, digs planned (n)=2
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 13
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 13
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 14
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 14
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 15
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 15
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 16
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 16
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 17
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 17
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 18
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 18
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 19
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 19
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 20
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 20
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 21
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 21
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 22
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 22
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 23
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 23
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 24
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 24
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 25
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 25
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 26
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 26
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 27
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 27
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 28
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 28
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 29
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 29
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 30
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 30
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 31
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 31
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 32
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 32
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 33
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 33
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 34
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 34
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 35
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 35
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 36
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 36
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 37
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 37
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 38
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 38
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 39
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 39
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 40
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 40
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 41
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 41
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 42
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 42
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 43
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 43
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 44
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 44
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 45
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 45
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 unit_20 assigned to clear_rubble (for factory_1)
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: topping up battery
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: unit moving to (14, 2)
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=1.0, value to move=0.5396835438487292
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: digs_required=12, digs planned (n)=12
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.5396835438487292
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.6746044298109115, value to move=0.6195890262403264
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: digs_required=12, digs planned (n)=12
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.6195890262403264
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.774486282800408, value to move=0.4419551846066451
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: digs_required=12, digs planned (n)=1
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 46
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 46
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 unit_22 assigned to clear_rubble (for factory_5)
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: topping up battery
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: unit moving to (34, 30)
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=1.0, value to move=0.6084321870244344
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: digs_required=7, digs planned (n)=7
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.6084321870244344
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.7605402337805429, value to move=0.6246480230843844
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: digs_required=9, digs planned (n)=9
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.6246480230843844
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.7808100288554805, value to move=0.0
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: digs_required=8, digs planned (n)=8
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 47
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 47
#
# player_0, main.py: INFO:root:player_0 unit_17 assigned to clear_rubble (for factory_2)
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: topping up battery
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: unit moving to (18, 13)
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=1.0, value to move=0.6481102703598551
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=11, digs planned (n)=11
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.6481102703598551
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.8101378379498189, value to move=0.7834579711804041
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=14, digs planned (n)=14
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.7834579711804041
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_1, main.py: INFO:root:player_1 unit_21 assigned to clear_rubble (for factory_3)
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: topping up battery
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.979322463975505, value to move=0.7654341881766937
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=14, digs planned (n)=2
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: unit moving to (28, 20)
#
# player_0, main.py: INFO:root:player_0 unit_19 assigned to clear_rubble (for factory_6)
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: topping up battery
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: unit moving to (36, 23)
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=1.0, value to move=0.4925986135346328
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: digs_required=7, digs planned (n)=7
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.4925986135346328
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=1.0, value to move=0.6799124269307113
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=11, digs planned (n)=11
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.615748266918291, value to move=0.6203374773276957
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.6799124269307113
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.7754218466596197, value to move=0.6322820211961395
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: digs_required=12, digs planned (n)=12
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.8498905336633891, value to move=0.5439299415445691
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=11, digs planned (n)=11
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.6322820211961395
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.5439299415445691
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.7903525264951744, value to move=0.5740805582194676
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: digs_required=11, digs planned (n)=8
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.6799124269307113, value to move=0.4351439532356552
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=11, digs planned (n)=6
#
# player_1, main.py: INFO:root:player_1 unit_23 assigned to clear_rubble (for factory_7)
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: topping up battery
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: unit moving to (43, 19)
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=1.0, value to move=0.6784556895587149
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: digs_required=12, digs planned (n)=12
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.6784556895587149
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.8480696119483936, value to move=0.0
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: digs_required=12, digs planned (n)=12
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 48
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 48
#
# player_0, main.py: INFO:root:Enemy Units: Removing unit unit_20, assumed dead
#
# player_0, main.py: INFO:root:Enemy unit_20: Enemy unit unit_20 dead, nothing more to do
#
# player_1, main.py: INFO:root:player_1: Step 38 - Friendly Units: Removing unit unit_20, assumed dead
#
# player_1, main.py: INFO:root:Step 38, Unit unit_20: Friendly unit unit_20 dead, removing from factory_1 units also
#
# player_0, main.py: INFO:root:player_0 unit_16 assigned to clear_rubble (for factory_0)
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: topping up battery
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: unit moving to (32, 13)
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=1.0, value to move=0.6292071400651321
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=11, digs planned (n)=11
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.6292071400651321
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.7865089250814151, value to move=0.7376915032380535
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=10, digs planned (n)=10
#
# player_1, main.py: INFO:root:factory_1 building Light
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {'factory_1': 0}
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.7376915032380535
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.9221143790475669, value to move=0.7214345693254374
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=10, digs planned (n)=7
#
# player_0, main.py: INFO:root:player_0 unit_18 assigned to clear_rubble (for factory_4)
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: topping up battery
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: unit moving to (32, 14)
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=1.0, value to move=0.7928885197024185
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=10, digs planned (n)=10
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.7928885197024185
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.991110649628023, value to move=0.5464129322173734
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=11, digs planned (n)=11
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.5464129322173734
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.6830161652717167, value to move=0.5643725885214809
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=11, digs planned (n)=6
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 49
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 49
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {}
#
# player_1, main.py: INFO:root:player_1 unit_24 assigned to clear_rubble (for factory_1)
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: topping up battery
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: unit moving to (13, 2)
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=1.0, value to move=0.43148696689706895
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: digs_required=1, digs planned (n)=1
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.43148696689706895
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.5393587086213362, value to move=0.23218210089413402
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: digs_required=12, digs planned (n)=12
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.23218210089413402
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.2902276261176675, value to move=0.3022771440898723
#
# player_1, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# ...
#
# player_0, main.py: INFO:root:factory_6 watering with water=736 and water_cost=4.0
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {'factory_0': 2, 'factory_4': 2, 'factory_6': 2}
#
# player_1, main.py: INFO:root:factory_3 watering with water=211 and water_cost=7.0
#
# player_1, main.py: INFO:root:factory_7 watering with water=550 and water_cost=5.0
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {'factory_3': 2, 'factory_7': 2}
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 996
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 996
#
# player_1, main.py: INFO:root:factory_3 watering with water=203 and water_cost=7.0
#
# player_1, main.py: INFO:root:factory_7 watering with water=544 and water_cost=5.0
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {'factory_3': 2, 'factory_7': 2}
#
# player_0, main.py: INFO:root:factory_0 watering with water=539 and water_cost=5.0
#
# player_0, main.py: INFO:root:factory_4 watering with water=407 and water_cost=6.0
#
# player_0, main.py: INFO:root:factory_6 watering with water=731 and water_cost=4.0
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {'factory_0': 2, 'factory_4': 2, 'factory_6': 2}
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 997
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 997
#
# player_1, main.py: INFO:root:factory_3 watering with water=195 and water_cost=7.0
#
# player_1, main.py: INFO:root:factory_7 watering with water=538 and water_cost=5.0
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {'factory_3': 2, 'factory_7': 2}
#
# player_0, main.py: INFO:root:factory_0 watering with water=533 and water_cost=5.0
#
# player_0, main.py: INFO:root:factory_4 watering with water=400 and water_cost=6.0
#
# player_0, main.py: INFO:root:factory_6 watering with water=726 and water_cost=4.0
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {'factory_0': 2, 'factory_4': 2, 'factory_6': 2}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 998
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 998
#
# player_1, main.py: INFO:root:factory_3 watering with water=187 and water_cost=7.0
#
# player_1, main.py: INFO:root:factory_7 watering with water=532 and water_cost=5.0
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {'factory_3': 2, 'factory_7': 2}
#
# player_0, main.py: INFO:root:factory_0 watering with water=527 and water_cost=5.0
#
# player_0, main.py: INFO:root:factory_4 watering with water=393 and water_cost=6.0
#
# player_0, main.py: INFO:root:factory_6 watering with water=721 and water_cost=4.0
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {'factory_0': 2, 'factory_4': 2, 'factory_6': 2}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 999
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 999
#
# player_0, main.py: INFO:root:factory_0 watering with water=521 and water_cost=5.0
#
# player_0, main.py: INFO:root:factory_4 watering with water=386 and water_cost=6.0
#
# player_0, main.py: INFO:root:factory_6 watering with water=716 and water_cost=4.0
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {'factory_0': 2, 'factory_4': 2, 'factory_6': 2}
#
# player_1, main.py: INFO:root:factory_3 watering with water=179 and water_cost=7.0
#
# player_1, main.py: INFO:root:factory_7 watering with water=526 and water_cost=5.0
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {'factory_3': 2, 'factory_7': 2}
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 1000
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 1000
#
# player_1, main.py: INFO:root:factory_1 watering with water=39 and water_cost=9.0
#
# player_1, main.py: INFO:root:factory_3 watering with water=196 and water_cost=7.0
#
# player_1, main.py: INFO:root:factory_5 watering with water=41 and water_cost=12.0
#
# player_1, main.py: INFO:root:factory_7 watering with water=545 and water_cost=5.0
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {'factory_1': 2, 'factory_3': 2, 'factory_5': 2, 'factory_7': 2}
#
# player_0, main.py: INFO:root:factory_0 watering with water=540 and water_cost=5.0
#
# player_0, main.py: INFO:root:factory_2 watering with water=35 and water_cost=10.0
#
# player_0, main.py: INFO:root:factory_4 watering with water=404 and water_cost=6.0
#
# player_0, main.py: INFO:root:factory_6 watering with water=736 and water_cost=4.0
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {'factory_0': 2, 'factory_2': 2, 'factory_4': 2, 'factory_6': 2}
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 1001
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 1001
#
# player_1, main.py: INFO:root:factory_1 watering with water=54 and water_cost=9.0
#
# player_1, main.py: INFO:root:factory_3 watering with water=213 and water_cost=7.0
#
# player_1, main.py: INFO:root:factory_5 watering with water=53 and water_cost=12.0
#
# player_1, main.py: INFO:root:factory_7 watering with water=564 and water_cost=5.0
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {'factory_1': 2, 'factory_3': 2, 'factory_5': 2, 'factory_7': 2}
#
# player_0, main.py: INFO:root:factory_0 watering with water=559 and water_cost=5.0
#
# player_0, main.py: INFO:root:factory_2 watering with water=48 and water_cost=11.0
#
# player_0, main.py: INFO:root:factory_4 watering with water=422 and water_cost=6.0
#
# player_0, main.py: INFO:root:factory_6 watering with water=756 and water_cost=4.0
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {'factory_0': 2, 'factory_2': 2, 'factory_4': 2, 'factory_6': 2}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 1002
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 1002
#
# player_1, main.py: INFO:root:factory_1 watering with water=44 and water_cost=9.0
#
# player_1, main.py: INFO:root:factory_3 watering with water=205 and water_cost=7.0
#
# player_1, main.py: INFO:root:factory_5 watering with water=40 and water_cost=12.0
#
# player_1, main.py: INFO:root:factory_7 watering with water=558 and water_cost=5.0
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {'factory_1': 2, 'factory_3': 2, 'factory_5': 2, 'factory_7': 2}
#
# player_0, main.py: INFO:root:factory_0 watering with water=553 and water_cost=5.0
#
# player_0, main.py: INFO:root:factory_2 watering with water=36 and water_cost=11.0
#
# player_0, main.py: INFO:root:factory_4 watering with water=415 and water_cost=6.0
#
# player_0, main.py: INFO:root:factory_6 watering with water=751 and water_cost=4.0
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {'factory_0': 2, 'factory_2': 2, 'factory_4': 2, 'factory_6': 2}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 1003
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 1003
#
# player_0, main.py: INFO:root:player_0 unit_45 assigned to clear_rubble (for factory_2)
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: topping up battery
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: unit moving to (14, 12)
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=1.0, value to move=0.7771553673422855
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=16, digs planned (n)=16
#
# player_1, main.py: INFO:root:factory_1 watering with water=34 and water_cost=9.0
#
# player_1, main.py: INFO:root:factory_3 watering with water=197 and water_cost=7.0
#
# player_1, main.py: INFO:root:factory_5 watering with water=27 and water_cost=12.0
#
# player_1, main.py: INFO:root:factory_7 watering with water=552 and water_cost=5.0
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {'factory_1': 2, 'factory_3': 2, 'factory_5': 2, 'factory_7': 2}
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.7771553673422855
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.9714442091778569, value to move=0.5217497698628283
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=10, digs planned (n)=9
#
# player_0, main.py: INFO:root:factory_0 watering with water=547 and water_cost=5.0
#
# player_0, main.py: INFO:root:factory_2 watering with water=24 and water_cost=11.0
#
# player_0, main.py: INFO:root:factory_4 watering with water=408 and water_cost=6.0
#
# player_0, main.py: INFO:root:factory_6 watering with water=746 and water_cost=4.0
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {'factory_0': 2, 'factory_2': 2, 'factory_4': 2, 'factory_6': 2}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 1004
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 1004
#
# player_1, main.py: INFO:root:factory_1 watering with water=24 and water_cost=9.0
#
# player_1, main.py: INFO:root:factory_3 watering with water=189 and water_cost=7.0
#
# player_1, main.py: INFO:root:factory_7 watering with water=546 and water_cost=5.0
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {'factory_1': 2, 'factory_3': 2, 'factory_7': 2}
#
# player_0, main.py: INFO:root:factory_0 watering with water=541 and water_cost=5.0
#
# player_0, main.py: INFO:root:factory_4 watering with water=401 and water_cost=6.0
#
# player_0, main.py: INFO:root:factory_6 watering with water=741 and water_cost=4.0
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {'factory_0': 2, 'factory_4': 2, 'factory_6': 2}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 1005
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 1005
#
# player_1, main.py: INFO:root:factory_1 watering with water=14 and water_cost=9.0
#
# player_1, main.py: INFO:root:factory_3 watering with water=181 and water_cost=7.0
#
# player_1, main.py: INFO:root:factory_7 watering with water=540 and water_cost=5.0
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {'factory_1': 2, 'factory_3': 2, 'factory_7': 2}
#
# player_0, main.py: INFO:root:factory_0 watering with water=535 and water_cost=5.0
#
# player_0, main.py: INFO:root:factory_4 watering with water=394 and water_cost=6.0
#
# player_0, main.py: INFO:root:factory_6 watering with water=736 and water_cost=4.0
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {'factory_0': 2, 'factory_4': 2, 'factory_6': 2}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 1006
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 1006
#
# player_1, main.py: INFO:root:factory_3 watering with water=173 and water_cost=7.0
#
# player_1, main.py: INFO:root:factory_7 watering with water=534 and water_cost=5.0
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {'factory_3': 2, 'factory_7': 2}
#
# player_0, main.py: INFO:root:factory_0 watering with water=529 and water_cost=5.0
#
# player_0, main.py: INFO:root:factory_4 watering with water=387 and water_cost=6.0
#
# player_0, main.py: INFO:root:factory_6 watering with water=731 and water_cost=4.0
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {'factory_0': 2, 'factory_4': 2, 'factory_6': 2}
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 1007
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 1007
#
# player_1, main.py: INFO:root:factory_3 watering with water=165 and water_cost=7.0
#
# player_1, main.py: INFO:root:factory_7 watering with water=528 and water_cost=5.0
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {'factory_3': 2, 'factory_7': 2}
#
# player_0, main.py: INFO:root:player_0 unit_36 assigned to clear_rubble (for factory_4)
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: topping up battery
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: unit moving to (36, 9)
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=1.0, value to move=0.5439568573898396
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=14, digs planned (n)=14
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.0, value to move=0.5439568573898396
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: adding move to better location
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: Value at pos=0.6799460717372995, value to move=0.6447253129312253
#
# player_0, main.py: INFO:root:RubbleRoutePlanner: digs_required=16, digs planned (n)=11
#
# player_0, main.py: INFO:root:factory_0 watering with water=523 and water_cost=5.0
#
# player_0, main.py: INFO:root:factory_4 watering with water=380 and water_cost=6.0
#
# player_0, main.py: INFO:root:factory_6 watering with water=726 and water_cost=4.0
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {'factory_0': 2, 'factory_4': 2, 'factory_6': 2}
#
# player_0, main.py: INFO:root:player_0 ======== Start of turn for player_0 ============
#
# player_1, main.py: INFO:root:player_1 ======== Start of turn for player_1 ============
#
# player_1, main.py: INFO:root:player_1 Beginning of step update for step 1008
#
# player_0, main.py: INFO:root:player_0 Beginning of step update for step 1008
#
# player_1, main.py: INFO:root:factory_3 watering with water=157 and water_cost=7.0
#
# player_1, main.py: INFO:root:factory_7 watering with water=522 and water_cost=5.0
#
# player_1, main.py: INFO:root:player_1 player_1 Factory actions: {'factory_3': 2, 'factory_7': 2}
#
# player_0, main.py: INFO:root:factory_0 watering with water=517 and water_cost=5.0
#
# player_0, main.py: INFO:root:factory_4 watering with water=373 and water_cost=6.0
#
# player_0, main.py: INFO:root:factory_6 watering with water=721 and water_cost=4.0
#
# player_0, main.py: INFO:root:player_0 player_0 Factory actions: {'factory_0': 2, 'factory_4': 2, 'factory_6': 2}
#
# 172.13218450546265

# %% [markdown]
# ## Just double click replay.html to open window in jupyter lab
# This is just a note for above. The replays work well in tabs

# %%
# import IPython
# IPython.display.HTML(filename='replay.html')
## This doesn't seem to show anything, don't know why.

# %%
raise
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 raise
#
# RuntimeError: No active exception to reraise

# %%
# !tar --exclude="*.tar.gz" --exclude="*.html" --exclude="*.ipynb" --exclude="*.json" --exclude="__pycache__" --exclude="_videos" --exclude="*.webm" --exclude="extracted_tar" --exclude=".ipynb_checkpoints" -cvzf submission.tar.gz *
# Out:
# a .gitignore
# a actions.py
# a agent.py
# a basic_agent.py
# a factory_manager.py
# a lux
# a main.py
# a master_state.py
# a mining_planner.py
# a pathfinding
# a path_finder.py
# a README.md
# a replay_jsons
# a rubble_clearing_planner.py
# a testing.py
# a unit_manager.py
# a util.py
# a __init__.py
# a pathfinding/core
# a pathfinding/finder
# a pathfinding/__init__.py
# a pathfinding/finder/a_star.py
# a pathfinding/finder/best_first.py
# a pathfinding/finder/bi_a_star.py
# a pathfinding/finder/breadth_first.py
# a pathfinding/finder/dijkstra.py
# a pathfinding/finder/finder.py
# a pathfinding/finder/ida_star.py
# a pathfinding/finder/msp.py
# a pathfinding/finder/__init__.py
# a pathfinding/core/diagonal_movement.py
# a pathfinding/core/grid.py
# a pathfinding/core/heuristic.py
# a pathfinding/core/node.py
# a pathfinding/core/util.py
# a pathfinding/core/__init__.py
# a lux/cargo.py
# a lux/config.py
# a lux/factory.py
# a lux/forward_sim.py
# a lux/kit.py
# a lux/team.py
# a lux/unit.py
# a lux/utils.py
# a lux/__init__.py

# %%
# !rm -r extracted_tar
# !mkdir extracted_tar
# !tar -xvf submission.tar.gz -C extracted_tar
# Out:
# x .gitignore
# x actions.py
# x agent.py
# x basic_agent.py
# x factory_manager.py
# x lux/
# x main.py
# x master_state.py
# x mining_planner.py
# x pathfinding/
# x path_finder.py
# x README.md
# x replay_jsons/
# x rubble_clearing_planner.py
# x testing.py
# x unit_manager.py
# x util.py
# x __init__.py
# x pathfinding/core/
# x pathfinding/finder/
# x pathfinding/__init__.py
# x pathfinding/finder/a_star.py
# x pathfinding/finder/best_first.py
# x pathfinding/finder/bi_a_star.py
# x pathfinding/finder/breadth_first.py
# x pathfinding/finder/dijkstra.py
# x pathfinding/finder/finder.py
# x pathfinding/finder/ida_star.py
# x pathfinding/finder/msp.py
# x pathfinding/finder/__init__.py
# x pathfinding/core/diagonal_movement.py
# x pathfinding/core/grid.py
# x pathfinding/core/heuristic.py
# x pathfinding/core/node.py
# x pathfinding/core/util.py
# x pathfinding/core/__init__.py
# x lux/cargo.py
# x lux/config.py
# x lux/factory.py
# x lux/forward_sim.py
# x lux/kit.py
# x lux/team.py
# x lux/unit.py
# x lux/utils.py
# x lux/__init__.py

# %%
print('"Traceback (most recent call last):\n  File \"/opt/conda/lib/python3.7/site-packages/kaggle_environments/agent.py\", line 50, in get_last_callable\n    exec(code_object, env)\n  File \"/kaggle_simulations/agent/main.py\", line 6, in <module>\n    from agent import Agent\n  File \"/kaggle_simulations/agent/agent.py\", line 18, in <module>\n    from unit_manager import UnitManager\n  File \"/kaggle_simulations/agent/unit_manager.py\", line 7, in <module>\n    from luxai2022.unit import UnitType\nModuleNotFoundError: No module named "luxai2022"\n\nDuring handling of the above exception, another exception occurred:\n\nTraceback (most recent call last):\n  File \"/opt/conda/lib/python3.7/site-packages/kaggle_environments/agent.py\", line 159, in act\n    action = self.agent(*args)\n  File \"/opt/conda/lib/python3.7/site-packages/kaggle_environments/agent.py\", line 125, in callable_agent\n    agent = get_last_callable(raw_agent, path=raw) or raw_agent\n  File \"/opt/conda/lib/python3.7/site-packages/kaggle_environments/agent.py\", line 64, in get"')

# %%
import json
from pprint import pprint
with open("zlog.json", 'r') as f:
    j = json.load(f)
# print(j[0][0]['stderr'])
pprint(j)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 import json
#       2 from pprint import pprint
# ----> 3 with open("zlog.json", 'r') as f:
#       4     j = json.load(f)
#       5 # print(j[0][0]['stderr'])
#
# File ~\.conda\envs\lux2022\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'zlog.json'
