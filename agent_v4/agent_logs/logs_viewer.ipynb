# %%
from pathlib import Path

# specify the folder path
folder_path = Path('.')

# get a list of all files in the folder
file_list = folder_path.glob('*.json')

# sort the list based on last modified time
file_list = sorted(file_list, key=lambda x: x.stat().st_mtime)

# print the list of files in order of last modified time
for file in file_list:
    print(file.name)
# Out:
# 49093796-1.json
# 49096028-0.json
# 49062496-1.json

# %%
latest_file = file_list[-1]
print(latest_file)
# Out:
# 49062496-1.json

# %%
import json
from pprint import pprint
with open(latest_file, 'r') as f:
    # lines = f.readlines()
    j = json.load(f)
# j = json.loads(lines[0])
pprint(j)
# Out:
# [[{'duration': 2.850002, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.001396, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.287305, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.001199, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.246303, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.002031, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.217819, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.002396, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.23151, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.002639, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.099309, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006901, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.003868, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006327, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.007326, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.005647, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006474, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.005468, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006076, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004268, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.00466, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004633, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006929, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004991, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006322, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004285, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004185, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.005544, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.073048, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.007005, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006307, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006315, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.010095, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.007147, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.007893, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006627, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004354, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006244, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006242, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004674, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006248, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004632, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004375, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.0073, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.007772, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.007383, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.007449, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004645, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006541, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006143, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.00681, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.007507, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006877, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006979, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.007303, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006767, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006523, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.005029, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004246, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004675, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.005301, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006544, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.007539, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.007636, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004285, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.007228, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006876, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004945, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006333, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004278, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006819, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006478, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004492, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004979, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006541, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.005298, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006305, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006564, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.005007, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004686, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.00782, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.007269, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004733, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006685, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006557, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006662, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.00664, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006743, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006513, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006279, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006875, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006293, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006496, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006417, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006761, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004435, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004863, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004936, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.005789, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006824, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.00593, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006938, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006995, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004308, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004495, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004814, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.007025, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004297, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.007169, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.005131, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004427, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.007313, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.005754, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006675, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.005977, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004216, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.0057, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006343, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006237, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.009049, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006039, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004078, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.007896, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006078, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.007219, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.005786, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.00684, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006003, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.00619, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006844, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.005332, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006066, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004496, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004643, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006019, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006041, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.0068, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004609, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004332, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.008475, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006762, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004148, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.00714, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.00589, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006272, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004123, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.005913, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006621, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.009262, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.005694, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004326, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004264, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006755, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.007703, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006228, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.004714, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.007789, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006696, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.009053, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006804, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006443, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.008543, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.005619, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006827, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.0044, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006398, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006965, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.006885, 'stderr': '', 'stdout': ''}],
#  [{'duration': 0.011742,
#    'stderr': 'Traceback (most recent call last):\n'
#              '  File '
#              '"/opt/conda/lib/python3.7/site-packages/kaggle_environments/agent.py", '
#              'line 159, in act\n'
#              '    action = self.agent(*args)\n'
#              '  File '
#              '"/opt/conda/lib/python3.7/site-packages/kaggle_environments/agent.py", '
#              'line 131, in callable_agent\n'
#              '    if callable(agent) \\\n'
#              '  File "/kaggle_simulations/agent/main.py", line 34, in '
#              'agent_fn\n'
#              '    actions = agent.act(step, obs, remainingOverageTime)\n'
#              '  File "/kaggle_simulations/agent/agent.py", line 82, in act\n'
#              '    self._beginning_of_step_update(step, obs, '
#              'remainingOverageTime)\n'
#              '  File "/kaggle_simulations/agent/agent.py", line 185, in '
#              '_beginning_of_step_update\n'
#              '    self.master.update(game_state)\n'
#              '  File "/kaggle_simulations/agent/master_state.py", line 367, in '
#              'update\n'
#              '    self._update_units(game_state)\n'
#              '  File "/kaggle_simulations/agent/master_state.py", line 394, in '
#              '_update_units\n'
#              '    self.units.update(game_state, self.player, '
#              'master_state=self)\n'
#              '  File "/kaggle_simulations/agent/master_state.py", line 218, in '
#              'update\n'
#              '    self.enemy.update(game_state, opp_',
#    'stdout': ''}]]

# %%
# Out:
# 1
