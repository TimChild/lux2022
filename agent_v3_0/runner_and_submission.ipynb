# %%
# %load_ext lab_black
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Run Agent against itself

# %%
import sys
import os
from pathlib import Path
import logging
from config import update_logging_level


def get_next_filename(folder_path, base_filename, extension):
    """Returns the next unique filename with an incrementing number."""
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

    i = 1
    while True:
        filename = f"{base_filename}_{i}.{extension}"
        file_path = os.path.join(folder_path, filename)
        if not os.path.exists(file_path):
            return file_path
        i += 1

# %%
# !luxai-s2 -h

# %%
# %cd D:/GitHub/lux2022


def run_games(html: bool, json: bool, seed: int):
    next_html_filename = get_next_filename(
        "agent_v3_0/local_replay_htmls", "replay", "html"
    )
    next_json_filename = get_next_filename(
        "agent_v3_0/local_replay_jsons", "replay", "json"
    )
    # if html:
    #     !luxai-s2 agent_v2_2/main.py agent_v2_2/main.py -v 2 -s {seed} -l 100 -o {next_html_filename}
    #     print(f"Done making HTML, moving onto JSON")
    # if json:
    #     !luxai-s2 agent_v2_2/main.py agent_v2_2/main.py -v 2 -s {seed} -l 100 --replay.save_format 'json' -o {next_json_filename}

    if html:
        # !luxai-s2 agent_v3_0/main.py basic_agent/main.py -v 2 -s {seed} -l 1000 -o {next_html_filename}
        # !luxai-s2 agent_v3_0/main.py agent_v3_0/main.py -v 2 -s {seed} -l 1000 -o {next_html_filename}
        print(f"Done making HTML, moving onto JSON")
    if json:
        # !luxai-s2 agent_v3_0/main.py basic_agent/main.py -v 2 -s {seed} -l 300 --replay.save_format 'json' -o {next_json_filename}


# for i in range(5):
#     run_games(True, False, 45342 + i)
run_games(True, False, 45342 + 1)
# !luxai-s2 agent_v2_2/main.py agent_v2_2/main.py -v 2 -s 45342 -l 1000 -o {next_html_filename}
# print(f"Done making HTML, moving onto JSON")
# !luxai-s2 agent_v2_2/main.py agent_v2_2/main.py -v 2 -s 45342 -l 1000 --replay.save_format 'json' -o {next_json_filename}
# Out:
# D:\GitHub\lux2022
# 40: Invalid movement action for unit [0] unit_20 UnitType.LIGHT at (20, 25) - Tried to move to (21, 25) requiring 1 power
# 41: Invalid movement action for unit [0] unit_20 UnitType.LIGHT at (20, 25) - Tried to move to (21, 25) requiring 1 power
# 42: Invalid movement action for unit [0] unit_20 UnitType.LIGHT at (20, 25) - Tried to move to (21, 25) requiring 1 power
# 43: Invalid movement action for unit [0] unit_20 UnitType.LIGHT at (20, 25) - Tried to move to (21, 25) requiring 1 power
# 43: Invalid movement action for unit [0] unit_23 UnitType.LIGHT at (17, 39) - Tried to move to (17, 40) requiring 1 power
# 44: Invalid movement action for unit [0] unit_20 UnitType.LIGHT at (20, 25) - Tried to move to (21, 25) requiring 1 power
# 44: Invalid movement action for unit [0] unit_22 UnitType.LIGHT at (37, 38) - Tried to move to (37, 39) requiring 3 power
# 44: Invalid movement action for unit [0] unit_23 UnitType.LIGHT at (17, 39) - Tried to move to (17, 40) requiring 1 power
# 45: Invalid movement action for unit [0] unit_20 UnitType.LIGHT at (20, 25) - Tried to move to (21, 25) requiring 1 power
# 45: Invalid movement action for unit [0] unit_22 UnitType.LIGHT at (37, 38) - Tried to move to (37, 39) requiring 3 power
# 45: Invalid movement action for unit [0] unit_23 UnitType.LIGHT at (17, 39) - Tried to move to (17, 40) requiring 1 power
# 46: Invalid movement action for unit [0] unit_20 UnitType.LIGHT at (20, 25) - Tried to move to (21, 25) requiring 1 power
# 46: Invalid movement action for unit [0] unit_22 UnitType.LIGHT at (37, 38) - Tried to move to (37, 39) requiring 3 power
# 46: Invalid movement action for unit [0] unit_23 UnitType.LIGHT at (17, 39) - Tried to move to (17, 40) requiring 1 power
# 47: Invalid movement action for unit [0] unit_20 UnitType.LIGHT at (20, 25) - Tried to move to (21, 25) requiring 1 power
# 47: Invalid movement action for unit [0] unit_22 UnitType.LIGHT at (37, 38) - Tried to move to (37, 39) requiring 3 power
# 47: Invalid movement action for unit [0] unit_23 UnitType.LIGHT at (17, 39) - Tried to move to (17, 40) requiring 1 power
# 48: Invalid movement action for unit [0] unit_20 UnitType.LIGHT at (20, 25) - Tried to move to (21, 25) requiring 1 power
# 48: Invalid movement action for unit [0] unit_22 UnitType.LIGHT at (37, 38) - Tried to move to (37, 39) requiring 3 power
# 48: Invalid movement action for unit [0] unit_23 UnitType.LIGHT at (17, 39) - Tried to move to (17, 40) requiring 1 power
# 49: Invalid movement action for unit [0] unit_20 UnitType.LIGHT at (20, 25) - Tried to move to (21, 25) requiring 1 power
# 49: Invalid movement action for unit [0] unit_22 UnitType.LIGHT at (37, 38) - Tried to move to (37, 39) requiring 3 power
# 49: Invalid movement action for unit [0] unit_23 UnitType.LIGHT at (17, 39) - Tried to move to (17, 40) requiring 1 power
# 49: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (15, 34) - Tried to move to (14, 34) requiring 1 power
# 50: Invalid movement action for unit [0] unit_20 UnitType.LIGHT at (20, 25) - Tried to move to (21, 25) requiring 1 power
# 50: Invalid movement action for unit [0] unit_22 UnitType.LIGHT at (37, 38) - Tried to move to (37, 39) requiring 3 power
# 50: Invalid movement action for unit [0] unit_23 UnitType.LIGHT at (17, 39) - Tried to move to (17, 40) requiring 1 power
# 50: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (15, 34) - Tried to move to (14, 34) requiring 1 power
# 51: Invalid movement action for unit [0] unit_22 UnitType.LIGHT at (37, 38) - Tried to move to (37, 39) requiring 3 power
# 52: Invalid movement action for unit [0] unit_22 UnitType.LIGHT at (37, 38) - Tried to move to (37, 39) requiring 3 power
# 54: Invalid movement action for unit [0] unit_20 UnitType.LIGHT at (22, 24) - Tried to move to (22, 23) requiring 2 power
# 55: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (39, 17) - Tried to move to (39, 16) requiring 4 power
# 56: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (39, 17) - Tried to move to (39, 16) requiring 4 power
# 58: Invalid movement action for unit [0] unit_20 UnitType.LIGHT at (21, 26) - Tried to move to (20, 26) requiring 2 power
# 58: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (39, 16) - Tried to move to (39, 17) requiring 3 power
# 59: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (39, 16) - Tried to move to (39, 17) requiring 3 power
# 59: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (13, 31) - Tried to move to (14, 31) requiring 2 power
# 60: Invalid movement action for unit [0] unit_20 UnitType.LIGHT at (20, 26) - Tried to move to (19, 26) requiring 2 power
# 61: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (14, 31) - Tried to move to (15, 31) requiring 2 power
# 63: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (15, 31) - Tried to move to (16, 31) requiring 2 power
# 64: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (38, 19) - Tried to move to (37, 19) requiring 3 power
# 65: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (38, 19) - Tried to move to (37, 19) requiring 3 power
# 65: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (16, 31) - Tried to move to (17, 31) requiring 2 power
# 66: Invalid movement action for unit [0] unit_20 UnitType.LIGHT at (19, 25) - Tried to move to (19, 26) requiring 2 power
# 66: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (24, 41) - Tried to move to (24, 42) requiring 3 power
# 67: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (37, 19) - Tried to move to (36, 19) requiring 3 power
# 67: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (17, 31) - Tried to move to (17, 32) requiring 2 power
# 68: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (37, 19) - Tried to move to (36, 19) requiring 3 power
# 68: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (24, 42) - Tried to move to (23, 42) requiring 2 power
# 70: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (36, 19) - Tried to move to (35, 19) requiring 2 power
# 70: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (23, 42) - Tried to move to (22, 42) requiring 2 power
# 72: Invalid movement action for unit [0] unit_20 UnitType.LIGHT at (19, 25) - Tried to move to (19, 26) requiring 2 power
# 72: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (35, 19) - Tried to move to (34, 19) requiring 2 power
# 72: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (22, 42) - Tried to move to (21, 42) requiring 2 power
# 73: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (35, 19) - Tried to move to (34, 19) requiring 2 power
# 74: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (21, 42) - Tried to move to (21, 43) requiring 2 power
# 75: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (34, 19) - Tried to move to (35, 19) requiring 2 power
# 75: Invalid movement action for unit [1] unit_29 UnitType.LIGHT at (41, 33) - Tried to move to (41, 32) requiring 3 power
# 76: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (21, 43) - Tried to move to (20, 43) requiring 2 power
# 76: Invalid movement action for unit [1] unit_27 UnitType.LIGHT at (29, 3) - Tried to move to (29, 4) requiring 4 power
# 77: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (35, 19) - Tried to move to (36, 19) requiring 3 power
# 77: Invalid movement action for unit [1] unit_27 UnitType.LIGHT at (29, 3) - Tried to move to (29, 4) requiring 4 power
# 78: Invalid movement action for unit [0] unit_20 UnitType.LIGHT at (19, 25) - Tried to move to (19, 26) requiring 2 power
# 78: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (35, 19) - Tried to move to (36, 19) requiring 3 power
# 78: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (20, 43) - Tried to move to (19, 43) requiring 2 power
# 79: Invalid movement action for unit [1] unit_29 UnitType.LIGHT at (40, 35) - Tried to move to (39, 35) requiring 3 power
# 80: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (36, 19) - Tried to move to (37, 19) requiring 3 power
# 80: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (19, 43) - Tried to move to (19, 44) requiring 2 power
# 80: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (13, 34) - Tried to move to (14, 34) requiring 2 power
# 80: Invalid movement action for unit [1] unit_29 UnitType.LIGHT at (40, 35) - Tried to move to (39, 35) requiring 3 power
# 81: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (36, 19) - Tried to move to (37, 19) requiring 3 power
# 81: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (19, 43) - Tried to move to (19, 44) requiring 2 power
# 81: Invalid movement action for unit [1] unit_27 UnitType.LIGHT at (28, 5) - Tried to move to (28, 6) requiring 1 power
# 81: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (13, 34) - Tried to move to (14, 34) requiring 2 power
# 81: Invalid movement action for unit [1] unit_29 UnitType.LIGHT at (40, 35) - Tried to move to (39, 35) requiring 3 power
# 82: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (36, 19) - Tried to move to (37, 19) requiring 3 power
# 82: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (19, 43) - Tried to move to (19, 44) requiring 2 power
# 82: Invalid movement action for unit [1] unit_27 UnitType.LIGHT at (28, 5) - Tried to move to (28, 6) requiring 1 power
# 82: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (13, 34) - Tried to move to (14, 34) requiring 2 power
# 82: Invalid movement action for unit [1] unit_29 UnitType.LIGHT at (40, 35) - Tried to move to (39, 35) requiring 3 power
# 83: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (36, 19) - Tried to move to (37, 19) requiring 3 power
# 83: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (19, 43) - Tried to move to (19, 44) requiring 2 power
# 83: Invalid movement action for unit [1] unit_27 UnitType.LIGHT at (28, 5) - Tried to move to (28, 6) requiring 1 power
# 83: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (13, 34) - Tried to move to (14, 34) requiring 2 power
# 83: Invalid movement action for unit [1] unit_29 UnitType.LIGHT at (40, 35) - Tried to move to (39, 35) requiring 3 power
# 84: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (36, 19) - Tried to move to (37, 19) requiring 3 power
# 84: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (19, 43) - Tried to move to (19, 44) requiring 2 power
# 84: Invalid movement action for unit [1] unit_27 UnitType.LIGHT at (28, 5) - Tried to move to (28, 6) requiring 1 power
# 84: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (13, 34) - Tried to move to (14, 34) requiring 2 power
# 84: Invalid movement action for unit [1] unit_29 UnitType.LIGHT at (40, 35) - Tried to move to (39, 35) requiring 3 power
# 85: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (36, 19) - Tried to move to (37, 19) requiring 3 power
# 85: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (19, 43) - Tried to move to (19, 44) requiring 2 power
# 85: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (13, 34) - Tried to move to (14, 34) requiring 2 power
# 86: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (36, 19) - Tried to move to (37, 19) requiring 3 power
# 86: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (19, 43) - Tried to move to (19, 44) requiring 2 power
# 86: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (13, 34) - Tried to move to (14, 34) requiring 2 power
# 87: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (36, 19) - Tried to move to (37, 19) requiring 3 power
# 87: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (19, 43) - Tried to move to (19, 44) requiring 2 power
# 87: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (13, 34) - Tried to move to (14, 34) requiring 2 power
# 88: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (36, 19) - Tried to move to (37, 19) requiring 3 power
# 88: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (19, 43) - Tried to move to (19, 44) requiring 2 power
# 88: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (13, 34) - Tried to move to (14, 34) requiring 2 power
# 89: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (36, 19) - Tried to move to (37, 19) requiring 3 power
# 89: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (19, 43) - Tried to move to (19, 44) requiring 2 power
# 89: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (13, 34) - Tried to move to (14, 34) requiring 2 power
# 90: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (36, 19) - Tried to move to (37, 19) requiring 3 power
# 90: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (19, 43) - Tried to move to (19, 44) requiring 2 power
# 90: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (13, 34) - Tried to move to (14, 34) requiring 2 power
# 91: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (36, 19) - Tried to move to (37, 19) requiring 3 power
# 91: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (19, 43) - Tried to move to (19, 44) requiring 2 power
# 91: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (13, 34) - Tried to move to (14, 34) requiring 2 power
# 92: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (36, 19) - Tried to move to (37, 19) requiring 3 power
# 92: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (19, 43) - Tried to move to (19, 44) requiring 2 power
# 92: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (13, 34) - Tried to move to (14, 34) requiring 2 power
# 93: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (36, 19) - Tried to move to (37, 19) requiring 3 power
# 93: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (19, 43) - Tried to move to (19, 44) requiring 2 power
# 93: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (13, 34) - Tried to move to (14, 34) requiring 2 power
# 94: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (36, 19) - Tried to move to (37, 19) requiring 3 power
# 94: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (19, 43) - Tried to move to (19, 44) requiring 2 power
# 94: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (13, 34) - Tried to move to (14, 34) requiring 2 power
# 95: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (36, 19) - Tried to move to (37, 19) requiring 3 power
# 95: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (19, 43) - Tried to move to (19, 44) requiring 2 power
# 95: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (13, 34) - Tried to move to (14, 34) requiring 2 power
# 96: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (36, 19) - Tried to move to (37, 19) requiring 3 power
# 96: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (19, 43) - Tried to move to (19, 44) requiring 2 power
# 96: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (13, 34) - Tried to move to (14, 34) requiring 2 power
# 97: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (36, 19) - Tried to move to (37, 19) requiring 3 power
# 97: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (19, 43) - Tried to move to (19, 44) requiring 2 power
# 97: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (13, 34) - Tried to move to (14, 34) requiring 2 power
# 98: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (36, 19) - Tried to move to (37, 19) requiring 3 power
# 98: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (19, 43) - Tried to move to (19, 44) requiring 2 power
# 98: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (13, 34) - Tried to move to (14, 34) requiring 2 power
# 99: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (36, 19) - Tried to move to (37, 19) requiring 3 power
# 99: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (19, 43) - Tried to move to (19, 44) requiring 2 power
# 99: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (13, 34) - Tried to move to (14, 34) requiring 2 power
# 100: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (36, 19) - Tried to move to (37, 19) requiring 3 power
# 100: Invalid movement action for unit [1] unit_26 UnitType.LIGHT at (19, 43) - Tried to move to (19, 44) requiring 2 power
# 100: Invalid movement action for unit [1] unit_28 UnitType.LIGHT at (13, 34) - Tried to move to (14, 34) requiring 2 power
# 101: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (36, 19) - Tried to move to (37, 19) requiring 3 power
# 103: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (37, 19) - Tried to move to (36, 19) requiring 3 power
# 104: Invalid movement action for unit [0] unit_24 UnitType.LIGHT at (37, 19) - Tried to move to (36, 19) requiring 3 power
# player_1, agent_v3_0/main.py: Traceback (most recent call last):
#
# player_1, agent_v3_0/main.py:   File "main.py", line 60, in <module>
#
# player_1, agent_v3_0/main.py:     actions = agent_fn(observation, dict(env_cfg=configurations))
#
# player_1, agent_v3_0/main.py:   File "main.py", line 34, in agent_fn
#
# player_1, agent_v3_0/main.py:     actions = agent.act(step, obs, remainingOverageTime)
#
# player_1, agent_v3_0/main.py:   File "D:\GitHub\lux2022\agent_v3_0\agent.py", line 101, in act
#
# player_1, agent_v3_0/main.py:     self.unit_action_planner.update(
#
# player_1, agent_v3_0/main.py:   File "D:\GitHub\lux2022\agent_v3_0\unit_action_planner.py", line 546, in update
#
# player_1, agent_v3_0/main.py:     self.all_upcoming_collisions = self._calculate_collisions()
#
# player_1, agent_v3_0/main.py:   File "D:\GitHub\lux2022\agent_v3_0\unit_action_planner.py", line 623, in _calculate_collisions
#
# player_1, agent_v3_0/main.py:     all_collisions = calculate_collisions(
#
# player_1, agent_v3_0/main.py:   File "D:\GitHub\lux2022\agent_v3_0\collisions.py", line 772, in calculate_collisions
#
# player_1, agent_v3_0/main.py:     light=find_collisions(
#
# player_1, agent_v3_0/main.py:   File "D:\GitHub\lux2022\agent_v3_0\collisions.py", line 77, in find_collisions
#
# player_1, agent_v3_0/main.py:     other_path = sanitize_path_start(other_path, other, rubble)
#
# player_1, agent_v3_0/main.py:   File "D:\GitHub\lux2022\agent_v3_0\collisions.py", line 51, in sanitize_path_start
#
# player_1, agent_v3_0/main.py:     path = check_next_move_will_happen(path, unit, rubble)
#
# player_1, agent_v3_0/main.py:   File "D:\GitHub\lux2022\agent_v3_0\collisions.py", line 39, in check_next_move_will_happen
#
# player_1, agent_v3_0/main.py:     move_cost = unit.unit_config.MOVE_COST + unit.unit_config.RUBBLE_MOVEMENT_COST * rubble[path[1][0], path[1][1]]
#
# player_1, agent_v3_0/main.py: IndexError: index 48 is out of bounds for axis 1 with size 48
#
# player_1, agent_v3_0/main.py: cannot parse action ''
# player_1 sent a invalid action None. Agent likely errored out somewhere, check above for stderr logs
# 115: [Player 1] Inappropriate action given. invalid
# Traceback (most recent call last):
#   File "C:\Users\Child\.conda\envs\lux2022\lib\site-packages\luxai_s2\env.py", line 808, in step
#     for unit_id, action in unit_actions.items():
# AttributeError: 'NoneType' object has no attribute 'items'
#
# 45.60336637496948
# Done making HTML, moving onto JSON

# %% [markdown]
# ## Just double click replay.html to open window in jupyter lab
# This is just a note for above. The replays work well in tabs

# %%
# import IPython
# IPython.display.HTML(filename='replay.html')
## This doesn't seem to show anything, don't know why.

# %%
raise
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 raise
#
# RuntimeError: No active exception to reraise

# %%
# %cd D:/GitHub/lux2022/agent_v3_0

submission_name = "v3_0_0"
# !tar --exclude="*.tar.gz" --exclude="*.html" --exclude="*.ipynb" --exclude="replay_jsons" --exclude=".gitignore" --exclude="*.log" --exclude="*.json" --exclude="__pycache__" --exclude="_videos" --exclude="*.webm" --exclude="extracted_tar" --exclude=".ipynb_checkpoints" --exclude="local_replay_htmls" --exclude="local_replay_jsons" -cvzf {submission_name}.tar.gz *

# %%
# !rm -r extracted_tar
# !mkdir extracted_tar
# !tar -xvf submission.tar.gz -C extracted_tar

# %%
print('"Traceback (most recent call last):\n  File \"/opt/conda/lib/python3.7/site-packages/kaggle_environments/agent.py\", line 50, in get_last_callable\n    exec(code_object, env)\n  File \"/kaggle_simulations/agent/main.py\", line 6, in <module>\n    from agent import Agent\n  File \"/kaggle_simulations/agent/agent.py\", line 18, in <module>\n    from unit_manager import UnitManager\n  File \"/kaggle_simulations/agent/unit_manager.py\", line 7, in <module>\n    from luxai2022.unit import UnitType\nModuleNotFoundError: No module named "luxai2022"\n\nDuring handling of the above exception, another exception occurred:\n\nTraceback (most recent call last):\n  File \"/opt/conda/lib/python3.7/site-packages/kaggle_environments/agent.py\", line 159, in act\n    action = self.agent(*args)\n  File \"/opt/conda/lib/python3.7/site-packages/kaggle_environments/agent.py\", line 125, in callable_agent\n    agent = get_last_callable(raw_agent, path=raw) or raw_agent\n  File \"/opt/conda/lib/python3.7/site-packages/kaggle_environments/agent.py\", line 64, in get"')
